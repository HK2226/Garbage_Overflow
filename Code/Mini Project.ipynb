# %%
# !pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
dirc = "D:\\Mini Project\\work\\Dataset\\train"
cat = ["clean","dirty"]

# %%
for c in cat:
    path = os.path.join(dirc,c)
    for img in os.listdir(path):
        img_arr = cv2.imread(os.path.join(path,img))

# %%
plt.imshow(img_arr)
plt.show()

# %%
img_arr.size
# Out:
# 718200
